# %% [markdown]
# <a href="https://colab.research.google.com/github/Shadatali1/Python/blob/main/printing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello Python! This is the complete true file for the objective' )
# Out:
# Hello Python! This is the complete true file for the objective
