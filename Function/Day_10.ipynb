# %% [markdown]
# # **Nested Functions (Function inside Function)**

# %% [markdown]
# **Simple Meaning**
#
# 👉 A function inside another function
#
# 💡 One function can use another function inside it

# %% [markdown]
# ### Story Time
#
# Think of a company 🏢
#
# Manager 👨‍💼 → main function
# Worker 👷 → inner function
#
# Manager tells worker what to do
#
# 💡 Worker (inner function) works inside manager only

# %% [markdown]
# ### Python Example

# %%
def outer():
    print("I am outer function")

    def inner():
        print("I am inner function")

    inner()

# %% [markdown]
# **Call Function**

# %%
outer()
# Out:
# I am outer function
# I am inner function

# %% [markdown]
# **Important Rule**
#
# ❌ You CANNOT call inner function outside
#
# inner()   # ERROR ❌
#
# Because inner function is hidden inside

# %% [markdown]
# ### Python Example

# %%
def calculator(a, b):

    def add():
        return a + b

    def multiply():
        return a * b

    print("Sum:", add())
    print("Multiply:", multiply())

# %%
calculator(5, 3)
# Out:
# Sum: 8
# Multiply: 15

# %% [markdown]
# ### Why Use Nested Functions?
#
# ✔ Organize code\
# ✔ Hide logic\
# ✔ Improve security\
# ✔ Used in AI & advanced coding

# %% [markdown]
# ### Practice Time 🎯
# ✅ **Task 1:**\
# def greet():
#
#     def message():
#         print("Hello student")
#
#     message()
#
# 👉 Call greet()

# %%
def greet(name):
    def message(name):
        print(name , "Hello Student")
    message(name)

greet('Shadat Ali')
# Out:
# Shadat Ali Hello Student

# %% [markdown]
# ✅ **Task 2:**\
# def math_ops(a, b):
#
#     def sub():
#         return a - b
#
#     def div():
#         return a / b
#
#     print(sub())
#     print(div())
#
# 👉 Try different values

# %%
def math_op(a , b):
    def sub():
        return a - b
    def div():
        return a / b
    print(sub())
    print(div())

math_op(3, 7)
# Out:
# -4
# 0.42857142857142855

# %% [markdown]
# **Task 3:**\
# def student(name):
#
#     def show():
#         print("Student name:", name)
#
#     show()
#
# 👉 Test with different names

# %%
def student(name):
    def show():
        return ("Student name", name)

    x = show()
    print(x)

student("Shadat Ali")
# Out:
# ('Student name', 'Shadat Ali')

# %% [markdown]
# ### Mini Challenge (Smart Brain 🤖)
#
# 👉 Create:

# %%
def robot(name):
    def task():
        return (name , "is working")
    x = task()
    print(x)

robot('Shadat Ali')
# Out:
# ('Shadat Ali', 'is working')
